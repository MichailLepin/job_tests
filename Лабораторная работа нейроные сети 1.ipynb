# %%
import numpy as np

def act(x):
    return 0 if x < 0.5 else 1

def go(var1, var2, var3, var4, var5, var6, var7):
    x = np.array([var1, var2, var3, var4, var5, var6, var7])
    w11 = [0.5, 0.5, 0, 0,-0.5, 0, 0]
    w12 = [0, 0, 0, -0.2, 0, 0.7, -0.3]
    w13 = [0, 0.3, 0.4, 0.3, -0.5, 0, 0]
    weight1 = np.array([w11, w12, w13])  # матрица 3x7
    weight2 = np.array([0.5, -0.4, 0.5])     # вектор 1х3

    sum_hidden = np.dot(weight1, x)       # вычисляем сумму на входах нейронов скрытого слоя
    print("Значения сумм на нейронах скрытого слоя: "+str(sum_hidden))

    out_hidden = np.array([act(x) for x in sum_hidden])
    print("Значения на выходах нейронов скрытого слоя: "+str(out_hidden))

    sum_end = np.dot(weight2, out_hidden)
    y = act(sum_end)
    print("Выходное значение НС: "+str(y))

    return y

var1 = int(input("Введите 1, если преподаватель доброжелателен: "))
var2 = int(input("Введите 1, если преподаватель интересно преподносит материал: "))
var3 = int(input("Введите 1, если предмет затрагивает интересующую вас тему/область: "))
var4 = int(input("Введите 1, если предмен пpaктикo-opиeнтиpoвaнный: "))
var5 = int(input("Введите 1, если преподаватель берет материалы для лекций или заданий из открытых источников: "))
var6 = int(input("Введите 1, если у предмета строгая система оценивания: "))
var7 = int(input("Введите 1, если по предмету есть автоматы: "))

res = go(var1, var2, var3, var4, var5, var6, var7)
if res == 1:
    print("Предмет супер")
else:
    print("Предмет отстой")
# Out:
# Введите 1, если преподаватель доброжелателен:  1
# Введите 1, если преподаватель интересно преподносит материал:  1
# Введите 1, если предмет затрагивает интересующую вас тему/область:  1
# Введите 1, если предмен пpaктикo-opиeнтиpoвaнный:  1
# Введите 1, если преподаватель берет материалы для лекций или заданий из открытых источников:  1
# Введите 1, если у предмета строгая система оценивания:  1
# Введите 1, если по предмету есть автоматы:  1
# Значения сумм на нейронах скрытого слоя: [0.5 0.2 0.5]
# Значения на выходах нейронов скрытого слоя: [1 0 1]
# Выходное значение НС: 1
# Предмет супер

# %%
import numpy as np
import time

start_time = time.time()


def act(x):
    return 0 if x < 0.5 else 1


def go(my_list): # перепишем ф-цию, чтобы она могла принимать на вход лист
    x = np.array(my_list)
    w11 = [0.5, 0.5, 0, 0,-0.5, 0, 0]
    w12 = [0, 0, 0, -0.2, 0, 0.7, -0.3]
    w13 = [0, 0.3, 0.4, 0.3, -0.5, 0, 0]
    weight1 = np.array([w11, w12, w13]) # матрица 3x7
    weight2 = np.array([0.5, -0.4, 0.5]) # вектор 1х3

    sum_hidden = np.dot(weight1, x) # вычисляем сумму на входах нейронов
    # скрытого слоя
    #print("Значения сумм на нейронах скрытого слоя: "+str(sum_hidden))
    out_hidden = np.array([act(x) for x in sum_hidden])
    #print("Значения на выходах нейронов скрытого слоя: "+str(out_hidden))
    sum_end = np.dot(weight2, out_hidden)
    y = act(sum_end)
    #print("Выходное значение НС: "+str(y))
    return y


def generate_data():
    my_data = []
    n = 0
    while '{0:07b}'.format(n) != '{0:07b}'.format(128):
        my_data.append(list('{0:07b}'.format(n)))
        n += 1
    return my_data

data = generate_data()
output = []
for i in data:
    local = []
    for j in i: #создадим цикл для формирования локального листа с интеджерами 
        local.append(int(j)) # так как наша функция возвращает лист листов строк
    local.append(go(local)) # а для использования данных в ф-ции нс необходимы интеджеры
    output.append(tuple(local)) #плюс сразу используем эту переменную для формирования листа кортежей

    
def f(x):
    return 2/(1 + np.exp(-x)) - 1

def df(x):
    return 0.5*(1 + x)*(1 - x)

W1 = np.array([[-0.2, 0.3, -0.4, 0, 0, 0, 0], [0.1, 0, 0, -0.3, 0, 0, -0.4], [0, 0, 0, 0, 0, -0.4, 0.1]])
W2 = np.array([0.2, 0.3, 0.5])

def go_forward(inp):
    sum = np.dot(W1, inp)
    out = np.array([f(x) for x in sum])

    sum = np.dot(W2, out)
    y = f(sum)
    return (y, out)

def train(epoch):
    global W2, W1
    lmd = 0.001          # шаг обучения
    N = 10000000           # число итераций при обучении
    count = len(epoch)
    for k in range(N):
        x = epoch[np.random.randint(0, count)]  # случайных выбор входного сигнала из обучающей выборки
        y, out = go_forward(x[0:7])             # прямой проход по НС и вычисление выходных значений нейронов
        e = y - x[-1]                           # ошибка
        delta = e*df(y)                         # локальный градиент
        W2[0] = W2[0] - lmd * delta * out[0]    # корректировка веса первой связи
        W2[1] = W2[1] - lmd * delta * out[1]    # корректировка веса второй связи
        W2[2] = W2[2] - lmd * delta * out[2]    # корректировка веса третьей связи
        
        delta2 = W2*delta*df(out)               # вектор из 3-х величин локальных градиентов

        # корректировка связей первого слоя
        W1[0, :] = W1[0, :] - np.array(x[0:7]) * delta2[0] * lmd
        W1[1, :] = W1[1, :] - np.array(x[0:7]) * delta2[1] * lmd
        W1[2, :] = W1[2, :] - np.array(x[0:7]) * delta2[2] * lmd
        
# обучающая выборка (она же полная выборка)
epoch = output

train(epoch)        # запуск обучения сети

# проверка полученных результатов
final = []
for x in epoch:
    y, out = go_forward(x[0:7])
    if round(y) == x[-1] or round(y) == -1:
        final.append(1)
    else:
        final.append(0)
    print(f"Выходное значение НС: {y} => {x[-1]}", round(y) == x[-1] or round(y) == -1)
print()
print("Веса: ", W1, W2)
print("Процент ошибки:", final.count(0)/len(final) * 100)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Выходное значение НС: 0.0 => 0 True
# Выходное значение НС: -0.16512854398029087 => 0 True
# Выходное значение НС: 0.0013803371845435564 => 0 True
# Выходное значение НС: -0.15578247628611552 => 0 True
# Выходное значение НС: 0.04337349255522449 => 0 True
# Выходное значение НС: 0.04792729100787119 => 0 True
# Выходное значение НС: 0.0185321299650405 => 0 True
# Выходное значение НС: 0.01892837523068902 => 0 True
# Выходное значение НС: 0.19852422080278598 => 0 True
# Выходное значение НС: 0.04049965065571204 => 0 True
# Выходное значение НС: 0.21937645575998288 => 0 True
# Выходное значение НС: 0.14066110434990753 => 0 True
# Выходное значение НС: 0.12983989058784262 => 0 True
# Выходное значение НС: 0.1637256369040696 => 0 True
# Выходное значение НС: 0.03189426955549313 => 0 True
# Выходное значение НС: 0.030952897862334794 => 0 True
# Выходное значение НС: 0.45208010330900716 => 0 True
# Выходное значение НС: 0.3470415498890891 => 0 True
# Выходное значение НС: 0.09215248161461176 => 0 True
# Выходное значение НС: 0.17094590693793843 => 0 True
# Выходное значение НС: 0.0560287795503942 => 0 True
# Выходное значение НС: 0.07322974104995295 => 0 True
# Выходное значение НС: 0.01455644048469007 => 0 True
# Выходное значение НС: 0.008898671990509976 => 0 True
# Выходное значение НС: 0.6630418921043897 => 1 True
# Выходное значение НС: 0.4527989147893179 => 1 False
# Выходное значение НС: 0.553189951019885 => 1 True
# Выходное значение НС: 0.6628981075671179 => 1 True
# Выходное значение НС: 0.10381696234212123 => 0 True
# Выходное значение НС: 0.14846328100355577 => 0 True
# Выходное значение НС: -0.005719673772414335 => 0 True
# Выходное значение НС: -0.04436178254717682 => 0 True
# Выходное значение НС: 0.9191886998260232 => 1 True
# Выходное значение НС: 0.9523496816404644 => 1 True
# Выходное значение НС: 0.5185613370361448 => 0 False
# Выходное значение НС: 0.8209818654596568 => 1 True
# Выходное значение НС: -0.3346831414204273 => 0 True
# Выходное значение НС: -0.4561169549129267 => 0 True
# Выходное значение НС: -0.06851270565459544 => 0 True
# Выходное значение НС: -0.18622441417896984 => 0 True
# Выходное значение НС: 0.9584419590603226 => 1 True
# Выходное значение НС: 0.9471777246732238 => 1 True
# Выходное значение НС: 0.9225884747141238 => 1 True
# Выходное значение НС: 0.9465308519560995 => 1 True
# Выходное значение НС: 0.15479619686116752 => 0 True
# Выходное значение НС: 0.3984086456462006 => 0 True
# Выходное значение НС: 0.08553349028718737 => 0 True
# Выходное значение НС: 0.09231114536915808 => 0 True
# Выходное значение НС: 0.9472070135132995 => 1 True
# Выходное значение НС: 0.9539075790976019 => 1 True
# Выходное значение НС: 0.8575015425810408 => 1 True
# Выходное значение НС: 0.9177144715354026 => 1 True
# Выходное значение НС: 0.2352644464384328 => 0 True
# Выходное значение НС: 0.3292646400256485 => 0 True
# Выходное значение НС: 0.11403285235539329 => 0 True
# Выходное значение НС: 0.17319228961209032 => 0 True
# Выходное значение НС: 0.950173955806916 => 1 True
# Выходное значение НС: 0.9064166526355004 => 1 True
# Выходное значение НС: 0.9593980618912161 => 1 True
# Выходное значение НС: 0.9500644191265064 => 1 True
# Выходное значение НС: 0.7737169107861424 => 1 True
# Выходное значение НС: 0.869756393920333 => 1 True
# Выходное значение НС: 0.4399167583230674 => 1 False
# Выходное значение НС: 0.6362048969558065 => 1 True
# Выходное значение НС: 0.9502774756463181 => 1 True
# Выходное значение НС: 0.9841870746737751 => 1 True
# Выходное значение НС: 0.4021249413129264 => 0 True
# Выходное значение НС: 0.7613556257226766 => 1 True
# Выходное значение НС: 0.07436114984836895 => 0 True
# Выходное значение НС: 0.11591834090793562 => 0 True
# Выходное значение НС: 0.01063851524384174 => 0 True
# Выходное значение НС: -0.0004917174025388382 => 0 True
# Выходное значение НС: 0.9922387657895888 => 1 True
# Выходное значение НС: 0.99462695013553 => 1 True
# Выходное значение НС: 0.9005514725145543 => 1 True
# Выходное значение НС: 0.9779190630113741 => 1 True
# Выходное значение НС: 0.11192260207945526 => 0 True
# Выходное значение НС: 0.24058715790225205 => 0 True
# Выходное значение НС: -0.04168748730962102 => 0 True
# Выходное значение НС: -0.10273030944229933 => 0 True
# Выходное значение НС: 0.9587646252506008 => 1 True
# Выходное значение НС: 0.9890140479872449 => 1 True
# Выходное значение НС: 0.29397471245431595 => 0 True
# Выходное значение НС: 0.7888532177875629 => 1 True
# Выходное значение НС: -0.030587279986646232 => 0 True
# Выходное значение НС: -0.07045622934020523 => 0 True
# Выходное значение НС: -0.04007780336903588 => 0 True
# Выходное значение НС: -0.10700852884968404 => 0 True
# Выходное значение НС: 0.9945460158233415 => 1 True
# Выходное значение НС: 0.99667029615037 => 1 True
# Выходное значение НС: 0.9267561102838182 => 1 True
# Выходное значение НС: 0.9851373538167525 => 1 True
# Выходное значение НС: -0.14192115146560602 => 0 True
# Выходное значение НС: 0.012135405589748238 => 0 True
# Выходное значение НС: -0.22056945816465712 => 0 True
# Выходное значение НС: -0.3687862384375218 => 0 True
# Выходное значение НС: 0.9994166514016745 => 1 True
# Выходное значение НС: 0.9976260598646263 => 1 True
# Выходное значение НС: 0.9992420860816691 => 0 False
# Выходное значение НС: 0.9995700255733724 => 1 True
# Выходное значение НС: 0.7888856371639408 => 1 True
# Выходное значение НС: 0.9492740523908623 => 1 True
# Выходное значение НС: 0.31944562265666865 => 0 True
# Выходное значение НС: 0.5598115694853951 => 1 True
# Выходное значение НС: 0.9973209259442868 => 1 True
# Выходное значение НС: 0.976326383005196 => 1 True
# Выходное значение НС: 0.9997510407458072 => 1 True
# Выходное значение НС: 0.9992023341817216 => 1 True
# Выходное значение НС: 0.9862268495630699 => 1 True
# Выходное значение НС: 0.9980993211492595 => 1 True
# Выходное значение НС: 0.7409268523550971 => 1 True
# Выходное значение НС: 0.9310120042532091 => 1 True
# Выходное значение НС: 0.999753414110498 => 1 True
# Выходное значение НС: 0.9988388130155408 => 1 True
# Выходное значение НС: 0.9996294206915766 => 1 True
# Выходное значение НС: 0.9997859248242391 => 1 True
# Выходное значение НС: 0.8579478230651887 => 1 True
# Выходное значение НС: 0.9728941490615477 => 1 True
# Выходное значение НС: 0.3846233067658278 => 0 True
# Выходное значение НС: 0.6466949445368473 => 1 True
# Выходное значение НС: 0.9983136645403599 => 1 True
# Выходное значение НС: 0.981188884940513 => 1 True
# Выходное значение НС: 0.9998258486830389 => 1 True
# Выходное значение НС: 0.9994427804676695 => 1 True
# Выходное значение НС: 0.9929995615647453 => 1 True
# Выходное значение НС: 0.9990516398303366 => 1 True
# Выходное значение НС: 0.8137786430603071 => 1 True
# Выходное значение НС: 0.9596290384671908 => 1 True
#
# Веса:  [[-1.27260805  3.7751845  -0.77647832 -1.49548939  3.96752857  1.00175758
#   -0.83195742]
#  [ 3.77765483 -3.17719699  0.64807646 -0.76029142  4.07503564  1.58863279
#   -0.85363114]
#  [ 0.43978481  1.78308879  0.21185067  1.18917865 -3.76172364 -1.34475091
#    0.72374567]] [2.3877291  3.8406699  6.20655725]
# Процент ошибки: 3.125
# --- 664.6600773334503 seconds ---

# %%
my_data = []
n = 0
while '{0:07b}'.format(n) != '{0:07b}'.format(128):
    my_data.append(list('{0:07b}'.format(n)))
    n += 1 
my_data
time
# Out:
# --- 0.000982046127319336 seconds ---

# %%
a = list('{0:07b}'.format(127))
tuple(a)
# Out:
# ('1', '1', '1', '1', '1', '1', '1')

# %%
import time
start_time = time.time()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.0 seconds ---

# %%
0.6//0.5
# Out:
# 1.0
